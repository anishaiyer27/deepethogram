# %%
import pandas as pd

# %%
# read csv as pandas dataframe
pilot_df = pd.read_csv("k934 Pilot Position Data.csv")
pilot_df.head()
# Out:
#       scorer DLC_mobnet_100_k934Jan28shuffle1_100000  \
# 0  bodyparts                               bodypart1
# 1     coords                                       x
# 2          0                      183.74688720703125
# 3          1                       188.9870147705078
# 4          2                       195.9990692138672
#
#   DLC_mobnet_100_k934Jan28shuffle1_100000.1  \
# 0                                 bodypart1
# 1                                         y
# 2                         267.8570251464844
# 3                        250.45738220214844
# 4                        231.02508544921875
#
#   DLC_mobnet_100_k934Jan28shuffle1_100000.2  \
# 0                                 bodypart1
# 1                                likelihood
# 2                        0.9984562397003174
# 3                        0.9965400695800781
# 4                        0.9989144802093506
#
#   DLC_mobnet_100_k934Jan28shuffle1_100000.3  \
# 0                                 bodypart2
# ...

# %%
pilot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18019 entries, 0 to 18018
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   scorer                                      18019 non-null  object
#  1   DLC_mobnet_100_k934Jan28shuffle1_100000     18019 non-null  object
#  2   DLC_mobnet_100_k934Jan28shuffle1_100000.1   18019 non-null  object
#  3   DLC_mobnet_100_k934Jan28shuffle1_100000.2   18019 non-null  object
#  4   DLC_mobnet_100_k934Jan28shuffle1_100000.3   18019 non-null  object
#  5   DLC_mobnet_100_k934Jan28shuffle1_100000.4   18019 non-null  object
#  6   DLC_mobnet_100_k934Jan28shuffle1_100000.5   18019 non-null  object
#  7   DLC_mobnet_100_k934Jan28shuffle1_100000.6   18019 non-null  object
#  8   DLC_mobnet_100_k934Jan28shuffle1_100000.7   18019 non-null  object
# ...

# %%
pilot_T = pilot_df.T
pilot_T
# Out:
#                                                 0           1      \
# scorer                                      bodyparts      coords
# DLC_mobnet_100_k934Jan28shuffle1_100000     bodypart1           x
# DLC_mobnet_100_k934Jan28shuffle1_100000.1   bodypart1           y
# DLC_mobnet_100_k934Jan28shuffle1_100000.2   bodypart1  likelihood
# DLC_mobnet_100_k934Jan28shuffle1_100000.3   bodypart2           x
# DLC_mobnet_100_k934Jan28shuffle1_100000.4   bodypart2           y
# DLC_mobnet_100_k934Jan28shuffle1_100000.5   bodypart2  likelihood
# DLC_mobnet_100_k934Jan28shuffle1_100000.6   bodypart3           x
# DLC_mobnet_100_k934Jan28shuffle1_100000.7   bodypart3           y
# DLC_mobnet_100_k934Jan28shuffle1_100000.8   bodypart3  likelihood
# DLC_mobnet_100_k934Jan28shuffle1_100000.9     objectA           x
# DLC_mobnet_100_k934Jan28shuffle1_100000.10    objectA           y
# DLC_mobnet_100_k934Jan28shuffle1_100000.11    objectA  likelihood
#
# ...

# %%
col_names = pilot_T.columns.values
grp_names = [col_names[i] for i in [0, 1]]
pilot_T = pilot_T.groupby(grp_names)
pilot_T
